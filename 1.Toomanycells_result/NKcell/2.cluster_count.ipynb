# %%
import scanpy as sc 
import numpy as np
import pandas as pd

# %%
adata = sc.read_h5ad('./data/NKcell_PDL1.h5ad')

# %%
cluster = ['t_ILC1-GZMK','t_ILC3-AREG']

# %%
for i in cluster:
    data = adata[adata.obs['Sub_Cluster']==i]
    tmc = pd.read_csv('./result/cluster/'+i+'_cluster.csv',usecols=['cell','cluster'],index_col=0)
    data.obs = data.obs.join(tmc)
    df = pd.DataFrame(data=np.unique(data.obs['cluster']),columns=['Cluster'])
    
    for j in df.index:
        df_data = data.obs[data.obs['cluster']==df.loc[j,'Cluster']]
        df.loc[j,'Count'] = len(df_data)
        df.loc[j,'PR_Count'] = len(df_data[df_data['Response']=='PR'])
        df.loc[j,'SD_Count'] = len(df_data[df_data['Response']=='SD'])
        
    df.loc[len(df)] = [0,len(data),len(data[data.obs['Response']=='PR']),len(data[data.obs['Response']=='SD'])]
    df = df.sort_values(by='Cluster')
    
    df['PR_Prop'] = df['PR_Count'] / df['Count']
    df['SD_Prop'] = df['SD_Count'] / df['Count']
    
    df.to_csv('./data/cluster_count/'+i+'_cluster_count.csv',index=False)

# %%
adata = adata[adata.obs['Sub_Cluster']=='t_Bmem-CD27']

# %%
adata[adata.obs['Response']=='PR']
# Out:
# View of AnnData object with n_obs × n_vars = 9174 × 27085
#     obs: 'CellName', 'ID', 'Sample', 'Patient', 'group', 'Tissue', 'Origin', 'Response', 'Timeline', 'Treatment', 'batch', 'n_genes', 'percent_mito', 'percent_hsp', 'percent_ig', 'percent_rp', 'n_counts', 'leiden', 'Louvain', 'myleiden', 'defcls', 'Global_Cluster', 'Sub_Cluster', 'Global_tSNE_1', 'Global_tSNE_2', 'Global_UMAP_1', 'Global_UMAP_2', 'Sub_tSNE_1', 'Sub_tSNE_2', 'Sub_UMAP_1', 'Sub_UMAP_2'

# %%
adata[adata.obs['Response']=='SD']
# Out:
# View of AnnData object with n_obs × n_vars = 890 × 27085
#     obs: 'CellName', 'ID', 'Sample', 'Patient', 'group', 'Tissue', 'Origin', 'Response', 'Timeline', 'Treatment', 'batch', 'n_genes', 'percent_mito', 'percent_hsp', 'percent_ig', 'percent_rp', 'n_counts', 'leiden', 'Louvain', 'myleiden', 'defcls', 'Global_Cluster', 'Sub_Cluster', 'Global_tSNE_1', 'Global_tSNE_2', 'Global_UMAP_1', 'Global_UMAP_2', 'Sub_tSNE_1', 'Sub_tSNE_2', 'Sub_UMAP_1', 'Sub_UMAP_2'

# %%
tmc = pd.read_csv('./result/cluster/t_Bmem-CD27_cluster.csv',usecols=['cell','cluster'],index_col=0)

# %%
tmc
# Out:
#                               cluster
# cell
# AACTCTTAGGACTGGT.Pre_P012_t         5
# ATTGGACCATGGAATA.Pre_P012_t         5
# CAAGATCGTGTGAATA.Pre_P012_t         5
# CCATTCGAGGTGCACA.Pre_P012_t         5
# CCTCTGAAGTACGTAA.Pre_P012_t         5
# ...                               ...
# TGCCAAAAGCTTATCG.Post_P019_t      104
# TGCCCTAGTCGAGATG.Post_P019_t      104
# TTCTACATCACCGTAA.Post_P019_t      104
# ATAACGCGTGGCCCTA.Pre_P004_t       104
# CTTAACTCAGTAAGCG.Pre_P004_t       104
#
# [10064 rows x 1 columns]

# %%
adata.obs = adata.obs.join(tmc)

# %%
np.unique(adata.obs['cluster'])
# Out:
# array([  5,   6,   8,   9,  12,  13,  15,  16,  20,  22,  23,  25,  27,
#         28,  32,  34,  35,  36,  39,  40,  42,  43,  49,  50,  52,  53,
#         56,  57,  58,  62,  63,  65,  67,  68,  71,  72,  74,  75,  79,
#         81,  82,  85,  86,  88,  89,  93,  94,  96,  97, 100, 101, 103,
#        104])

# %%
df = pd.DataFrame(data=np.unique(adata.obs['cluster']),columns=['Cluster'])

# %%
df.sor
# Out:
#     Cluster
# 0         5
# 1         6
# 2         8
# 3         9
# 4        12
# 5        13
# 6        15
# 7        16
# 8        20
# 9        22
# 10       23
# 11       25
# 12       27
# 13       28
# 14       32
# 15       34
# 16       35
# 17       36
# 18       39
# 19       40
# 20       42
# 21       43
# 22       49
# 23       50
# 24       52
# 25       53
# 26       56
# 27       57
# 28       58
# 29       62
# 30       63
# 31       65
# 32       67
# 33       68
# 34       71
# 35       72
# 36       74
# 37       75
# 38       79
# 39       81
# 40       82
# 41       85
# 42       86
# 43       88
# 44       89
# 45       93
# 46       94
# 47       96
# 48       97
# 49      100
# 50      101
# 51      103
# 52      104

# %%
for i in df.index:
    data = adata.obs[adata.obs['cluster']==df.loc[i,'Cluster']]
    df.loc[i,'Count'] = len(data)
    df.loc[i,'PR_Count'] = len(data[data['Response']=='PR'])
    df.loc[i,'SD_Count'] = len(data[data['Response']=='SD'])

# %%
df.
# Out:
#     Cluster  Count  PR_Count  SD_Count
# 0         5  296.0     290.0       6.0
# 1         6  274.0     273.0       1.0
# 2         8  231.0     198.0      33.0
# 3         9  279.0     159.0     120.0
# 4        12  228.0     197.0      31.0
# 5        13  299.0     114.0     185.0
# 6        15  170.0     144.0      26.0
# 7        16  248.0     206.0      42.0
# 8        20  396.0     392.0       4.0
# 9        22  164.0     160.0       4.0
# 10       23  222.0     216.0       6.0
# 11       25  408.0     401.0       7.0
# 12       27  205.0     171.0      34.0
# 13       28  234.0     182.0      52.0
# 14       32   51.0      50.0       1.0
# 15       34   33.0      10.0      23.0
# 16       35   46.0      35.0      11.0
# 17       36  194.0     163.0      31.0
# 18       39  190.0     186.0       4.0
# 19       40  209.0     200.0       9.0
# 20       42  189.0     168.0      21.0
# 21       43  209.0     165.0      44.0
# 22       49  197.0     193.0       4.0
# ...

# %%
df
# Out:
#     Cluster  Count  PR_Count  SD_Count
# 0         5  296.0     290.0       6.0
# 1         6  274.0     273.0       1.0
# 2         8  231.0     198.0      33.0
# 3         9  279.0     159.0     120.0
# 4        12  228.0     197.0      31.0
# 5        13  299.0     114.0     185.0
# 6        15  170.0     144.0      26.0
# 7        16  248.0     206.0      42.0
# 8        20  396.0     392.0       4.0
# 9        22  164.0     160.0       4.0
# 10       23  222.0     216.0       6.0
# 11       25  408.0     401.0       7.0
# 12       27  205.0     171.0      34.0
# 13       28  234.0     182.0      52.0
# 14       32   51.0      50.0       1.0
# 15       34   33.0      10.0      23.0
# 16       35   46.0      35.0      11.0
# 17       36  194.0     163.0      31.0
# 18       39  190.0     186.0       4.0
# 19       40  209.0     200.0       9.0
# 20       42  189.0     168.0      21.0
# 21       43  209.0     165.0      44.0
# 22       49  197.0     193.0       4.0
# ...

# %%
df.loc[len(df)] = [0,len(adata),len(adata[adata.obs['Response']=='PR']),len(adata[adata.obs['Response']=='SD'])]

# %%
df = df.sort_values(by='Cluster')

# %%
pd.concat([,df],axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ----> 1 pd.concat([[0,len(adata),len(adata[adata.obs['Response']=='PR']),len(adata[adata.obs['Response']=='SD'])],df],axis=1)
#
# File ~/python/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/python/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py:347, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
# ...

# %%
df['SD_Prop'] = df['SD_Count'] / df['Count']

# %%
df
# Out:
#     Cluster  Count  PR_Count  SD_Count
# 0         5  296.0     290.0       6.0
# 1         6  274.0     273.0       1.0
# 2         8  231.0     198.0      33.0
# 3         9  279.0     159.0     120.0
# 4        12  228.0     197.0      31.0
# 5        13  299.0     114.0     185.0
# 6        15  170.0     144.0      26.0
# 7        16  248.0     206.0      42.0
# 8        20  396.0     392.0       4.0
# 9        22  164.0     160.0       4.0
# 10       23  222.0     216.0       6.0
# 11       25  408.0     401.0       7.0
# 12       27  205.0     171.0      34.0
# 13       28  234.0     182.0      52.0
# 14       32   51.0      50.0       1.0
# 15       34   33.0      10.0      23.0
# 16       35   46.0      35.0      11.0
# 17       36  194.0     163.0      31.0
# 18       39  190.0     186.0       4.0
# 19       40  209.0     200.0       9.0
# 20       42  189.0     168.0      21.0
# 21       43  209.0     165.0      44.0
# 22       49  197.0     193.0       4.0
# ...

# %%
df.to_csv('./data/cluster_count.csv',index=False)
