# %%
import os

# %%
cluster = 't_Tact-XIST'

# %%
os.mkdir('./result/'+cluster+'_NR_E')
os.mkdir('./result/'+cluster+'_non-NR_E')

# %%
# run compass with micropooling 
# !compass --data data/Compass_input/{cluster}_NR_E.tsv \
    --num-processes 20 \
    --species homo_sapiens \
    --microcluster-size 10 \
    --output-dir result/{cluster}_NR_E/ \
    --temp-dir result/{cluster}_NR_E/temp_data/
# Out:
# Partitioning dataset into microclusters of size 10
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdff35d0a60>
# Traceback (most recent call last):
#   File "/data/hour/miniconda3/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/data/hour/miniconda3/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/data/hour/miniconda3/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/data/hour/miniconda3/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
# ...

# %%
# run compass with micropooling 
# !compass --data data/Compass_input/{cluster}_non-NR_E.tsv \
    --num-processes 20 \
    --species homo_sapiens \
    --microcluster-size 10 \
    --output-dir result/{cluster}_non-NR_E/ \
    --temp-dir result/{cluster}_non-NR_E/temp_data/
# Out:
# Partitioning dataset into microclusters of size 10
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f268b5cfa60>
# Traceback (most recent call last):
#   File "/data/hour/miniconda3/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/data/hour/miniconda3/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/data/hour/miniconda3/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/data/hour/miniconda3/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
# ...

# %%
cluster = 't_CD8_Trm-ZNF683'

# %%
os.mkdir('./result/'+cluster+'_NR_E')
os.mkdir('./result/'+cluster+'_non-NR_E')

# %%
# run compass with micropooling 
# !compass --data data/Compass_input/{cluster}_NR_E.tsv \
    --num-processes 20 \
    --species homo_sapiens \
    --microcluster-size 10 \
    --output-dir result/{cluster}_NR_E/ \
    --temp-dir result/{cluster}_NR_E/temp_data/
# Out:
# Partitioning dataset into microclusters of size 10
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f8d3dabaa60>
# Traceback (most recent call last):
#   File "/data/hour/miniconda3/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/data/hour/miniconda3/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/data/hour/miniconda3/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/data/hour/miniconda3/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
# ...

# %%
# run compass with micropooling 
# !compass --data data/Compass_input/{cluster}_non-NR_E.tsv \
    --num-processes 20 \
    --species homo_sapiens \
    --microcluster-size 10 \
    --output-dir result/{cluster}_non-NR_E/ \
    --temp-dir result/{cluster}_non-NR_E/temp_data/
# Out:
# Partitioning dataset into microclusters of size 10
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7ff25a2cca60>
# Traceback (most recent call last):
#   File "/data/hour/miniconda3/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/data/hour/miniconda3/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/data/hour/miniconda3/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/data/hour/miniconda3/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
# ...
